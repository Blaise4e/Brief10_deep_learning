# %% [markdown]
# # CIFAR Classification
#
# ### Exercise objectives
#
# - Implement a CNN for a 10-class classification problem
# - Enhance the CNN performance with data augmentation techniques
# - Experiment the acceleration of GPU for image processing (Google Colab)
#
# <hr>
# <hr>
#
# You should now have a better feeling of how a CNN is working, and especially how the convolutions are affecting the image to detect specific features. Therefore, let's now play with a bit more complex images.
#
# The CIFAR-10 dataset is a dataset that contains images of 10 different classes
#
# <img src="https://people.minesparis.psl.eu/fabien.moutarde/ES_MachineLearning/mini-projets/cifar10_notebook_fichiers/cifar_10.png">
#
# This dataset is emblematic in the research community as many enhancements for image problems have been achieved on this dataset, and later on the CIFAR-100 dataset once the performance got too high. You can check the [wikipedia](https://en.wikipedia.org/wiki/CIFAR-10) page of the dataset if you want to know more about it.
#
# In this notebook, we propose to implement a CNN to distinguish the 10 categories from the CIFAR-10 dataset. Again, remember that until 10 years ago, this problem was very challenging to the entire research community and is now for you to tackle.

# %% [markdown]
# ## 0. Colab
#
# **First, make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.

# %% [markdown]
# ## 1. Data
#
# We'll take care of data loading and preprocessing for you. Just run the following cells and make sure you understand them

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np

(images_train, labels_train), (images_test, labels_test) = cifar10.load_data()
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 7s 0us/step
# 170508288/170498071 [==============================] - 7s 0us/step
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %% [markdown]
# ❗️ 50,000 images may take a long time to train: **Always start with a subsample to iterate quickly** before scaling up
#
# Below, we divide the dataset size by `reduction_factor=10`. Don't try to increase it unless we ask you too.

# %%
# Reduce size
reduction_factor = 10

idx_train =  np.random.choice(len(images_train), round(len(images_train)/reduction_factor))
idx_test =  np.random.choice(len(images_test), round(len(images_test)/reduction_factor))

images_train_small = images_train[idx_train]
images_test_small = images_test[idx_test]
labels_train_small = labels_train[idx_train]
labels_test_small = labels_test[idx_test]

print(images_train.shape, images_test.shape)
unique, counts = np.unique(labels_train_small, return_counts=True)
dict(zip(unique, counts))
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# {0: 485,
#  1: 541,
#  2: 499,
#  3: 504,
#  4: 482,
#  5: 489,
#  6: 548,
#  7: 462,
#  8: 503,
#  9: 487}

# %%
# Let's plot few images to see what they look like
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
for i in range(6):
    plt.subplot(1,6, i+1)
    img = images_train[i]
    label = labels_train[i][0]
    plt.imshow(img)
    plt.title(labels[label])

# %% [markdown]
# And, as usual,
# - we normalize the data between 0 and 1
# - we create `y` as one-hot-encoded version of `labels`

# %%
X_train = images_train / 255.
X_train_small = images_train_small / 255.
X_test = images_test / 255.
X_test_small = images_test_small / 255.

from tensorflow.keras.utils import to_categorical
y_train = to_categorical(labels_train, 10)
y_train_small = to_categorical(labels_train_small, 10)
y_test = to_categorical(labels_test, 10)
y_test_small = to_categorical(labels_test_small, 10)

# %% [markdown]
# ## 2. Iterate on your CNN architecture using your small training set
#
#
# ❓ **Question** ❓ Your turn to shine!
#
# - Define the CNN architecture of your choice in a method `initialize_model()`
# - Compile your model in a method `compile_model()`:
# - Fit it on your **small** training set **only**
# - Store the output of the fit in an `history` variable
# - Try a first model yourself, before looking at PRO TIPS below
#
# <details>
#     <summary> 🆘 PRO TIPS 🆘  </summary>
#
#
# - Do not forget to add the input shape of your data to the first layer: it has 3 colors
# - Start simple, complexify after few trials to get better results
# - The task is complex: Try at least 3 or 4 convolutions
# - Kernel size do not need to be large for such small picture resolution!
# - Add some Maxpooling (but not too much else the activation "image" will become too small)
# - Keep padding = 'same' and 'stride' = (1,1) to start with.
# - Once your model overfits, try adding some dropout layer to regularize the network. A good tip is too increase dropout strengh as you move closer to the output, so as not to overfit on your end-result
# - Images are so small, that you can use larger batch size (32 or 64) to benefit from even more GPU parallelization
# </details>

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
num_classes = 10
input_shape = (32, 32, 3)
kernel = (3, 3)
def initialize_model():
    '''instanciate and return the CNN architecture of your choice with less than 150,000 params'''
    # YOUR CODE HERE
    model = Sequential()
    model.add(Conv2D(16, kernel_size=kernel, activation='selu', padding='Same', input_shape=input_shape))
    model.add(Conv2D(16, kernel_size=kernel, activation='selu',padding='Same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(32, kernel_size=kernel, activation='selu',padding='Same'))
    model.add(Conv2D(32, kernel_size=kernel, activation='selu',padding='Same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, kernel_size=kernel, activation='selu',padding='Same'))
    model.add(Conv2D(64, kernel_size=kernel, activation='selu',padding='Same'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(32, activation='selu'))
    model.add(Dense(64, activation='selu'))
    model.add(Dense(10, activation='selu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
import tensorflow
def compile_model(model):
    '''return a compiled model suited for the cifar tasks'''
    # YOUR CODE HERE
    #training
    batch_size = 50
    epochs = 75
    lrate = 0.03
    epsilon=1e-08
    decay=1e-4
    #optimizer = keras.optimizers.rmsprop(lr=lrate,decay=1e-4)
    optimizer = tensorflow.keras.optimizers.Adadelta(lr=lrate ) #, epsilon=epsilon, decay=decay)
    #optimizer = keras.optimizers.Adam(lr=lrate, beta_1=0.9, beta_2=0.999, epsilon=epsilon, decay=decay)

    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %% [markdown]
# ❓ **Question** ❓ Run the following function on the previous history (keep the default arguments, these are intended for future plots in the notebook).

# %%
model = initialize_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        448
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)        2320
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 16)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        4640
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          18496
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 32)                32800
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 10)                650
#
#  dense_3 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 107,752
# Trainable params: 107,752
# Non-trainable params: 0
# _________________________________________________________________

# %%
compile_model(model)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adadelta.py:74: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adadelta, self).__init__(name, **kwargs)

# %%
from tensorflow.keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min',verbose=1, patience=50, min_delta=0.005)
history = model.fit(X_train_small, y_train_small, batch_size=64, epochs=50, validation_split=0.3, verbose=1, callbacks=[es])
# Out:
# Epoch 1/50
# 55/55 [==============================] - 32s 30ms/step - loss: 2.3102 - accuracy: 0.1271 - val_loss: 2.1861 - val_accuracy: 0.1720
# Epoch 2/50
# 55/55 [==============================] - 1s 16ms/step - loss: 2.1057 - accuracy: 0.2177 - val_loss: 2.0606 - val_accuracy: 0.2227
# Epoch 3/50
# 55/55 [==============================] - 1s 16ms/step - loss: 2.0369 - accuracy: 0.2551 - val_loss: 2.0055 - val_accuracy: 0.2653
# Epoch 4/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.9887 - accuracy: 0.2743 - val_loss: 1.9659 - val_accuracy: 0.2747
# Epoch 5/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.9440 - accuracy: 0.2991 - val_loss: 1.9314 - val_accuracy: 0.2873
# Epoch 6/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.9075 - accuracy: 0.3126 - val_loss: 1.9092 - val_accuracy: 0.3080
# Epoch 7/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.8699 - accuracy: 0.3271 - val_loss: 1.8865 - val_accuracy: 0.3013
# Epoch 8/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.8337 - accuracy: 0.3429 - val_loss: 1.8622 - val_accuracy: 0.3387
# Epoch 9/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.8034 - accuracy: 0.3466 - val_loss: 1.8473 - val_accuracy: 0.3167
# Epoch 10/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.7729 - accuracy: 0.3746 - val_loss: 1.8242 - val_accuracy: 0.3307
# Epoch 11/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.7485 - accuracy: 0.3826 - val_loss: 1.8244 - val_accuracy: 0.3200
# Epoch 12/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.7228 - accuracy: 0.3951 - val_loss: 1.8015 - val_accuracy: 0.3420
# Epoch 13/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.6993 - accuracy: 0.3951 - val_loss: 1.7753 - val_accuracy: 0.3513
# Epoch 14/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.6821 - accuracy: 0.4169 - val_loss: 1.7556 - val_accuracy: 0.3500
# Epoch 15/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.6590 - accuracy: 0.4149 - val_loss: 1.7497 - val_accuracy: 0.3567
# Epoch 16/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.6388 - accuracy: 0.4257 - val_loss: 1.7349 - val_accuracy: 0.3640
# Epoch 17/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.6158 - accuracy: 0.4440 - val_loss: 1.7475 - val_accuracy: 0.3507
# Epoch 18/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.6040 - accuracy: 0.4511 - val_loss: 1.7303 - val_accuracy: 0.3620
# Epoch 19/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.5886 - accuracy: 0.4506 - val_loss: 1.7101 - val_accuracy: 0.3727
# Epoch 20/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.5700 - accuracy: 0.4566 - val_loss: 1.7024 - val_accuracy: 0.3767
# Epoch 21/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.5552 - accuracy: 0.4631 - val_loss: 1.7096 - val_accuracy: 0.3807
# Epoch 22/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.5405 - accuracy: 0.4694 - val_loss: 1.6912 - val_accuracy: 0.3853
# Epoch 23/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.5262 - accuracy: 0.4734 - val_loss: 1.6965 - val_accuracy: 0.3867
# Epoch 24/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.5123 - accuracy: 0.4871 - val_loss: 1.6714 - val_accuracy: 0.3967
# Epoch 25/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4968 - accuracy: 0.4826 - val_loss: 1.6610 - val_accuracy: 0.3927
# Epoch 26/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4867 - accuracy: 0.4894 - val_loss: 1.6531 - val_accuracy: 0.3980
# Epoch 27/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4689 - accuracy: 0.5011 - val_loss: 1.6590 - val_accuracy: 0.3960
# Epoch 28/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4585 - accuracy: 0.5103 - val_loss: 1.6522 - val_accuracy: 0.4060
# Epoch 29/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4459 - accuracy: 0.5183 - val_loss: 1.6838 - val_accuracy: 0.3873
# Epoch 30/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4324 - accuracy: 0.5134 - val_loss: 1.6297 - val_accuracy: 0.4280
# Epoch 31/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4183 - accuracy: 0.5209 - val_loss: 1.6664 - val_accuracy: 0.4007
# Epoch 32/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.4070 - accuracy: 0.5254 - val_loss: 1.6313 - val_accuracy: 0.4153
# Epoch 33/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.3969 - accuracy: 0.5337 - val_loss: 1.6213 - val_accuracy: 0.4113
# Epoch 34/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.3828 - accuracy: 0.5397 - val_loss: 1.6188 - val_accuracy: 0.4240
# Epoch 35/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.3702 - accuracy: 0.5409 - val_loss: 1.6397 - val_accuracy: 0.4107
# Epoch 36/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.3583 - accuracy: 0.5537 - val_loss: 1.6060 - val_accuracy: 0.4247
# Epoch 37/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.3479 - accuracy: 0.5551 - val_loss: 1.6148 - val_accuracy: 0.4227
# Epoch 38/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.3368 - accuracy: 0.5586 - val_loss: 1.6053 - val_accuracy: 0.4247
# Epoch 39/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.3265 - accuracy: 0.5666 - val_loss: 1.5978 - val_accuracy: 0.4180
# Epoch 40/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.3120 - accuracy: 0.5683 - val_loss: 1.5947 - val_accuracy: 0.4313
# Epoch 41/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.2992 - accuracy: 0.5737 - val_loss: 1.6111 - val_accuracy: 0.4253
# Epoch 42/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.2889 - accuracy: 0.5823 - val_loss: 1.5804 - val_accuracy: 0.4347
# Epoch 43/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.2779 - accuracy: 0.5863 - val_loss: 1.6135 - val_accuracy: 0.4053
# Epoch 44/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.2687 - accuracy: 0.5869 - val_loss: 1.6132 - val_accuracy: 0.4267
# Epoch 45/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.2590 - accuracy: 0.5897 - val_loss: 1.5924 - val_accuracy: 0.4120
# Epoch 46/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.2479 - accuracy: 0.6006 - val_loss: 1.5791 - val_accuracy: 0.4273
# Epoch 47/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.2366 - accuracy: 0.5929 - val_loss: 1.5771 - val_accuracy: 0.4467
# Epoch 48/50
# 55/55 [==============================] - 1s 17ms/step - loss: 1.2238 - accuracy: 0.6063 - val_loss: 1.5716 - val_accuracy: 0.4347
# Epoch 49/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.2157 - accuracy: 0.6080 - val_loss: 1.5629 - val_accuracy: 0.4360
# Epoch 50/50
# 55/55 [==============================] - 1s 16ms/step - loss: 1.2001 - accuracy: 0.6186 - val_loss: 1.5650 - val_accuracy: 0.4380

# %%
model.evaluate(X_test_small, y_test_small)
# Out:
# 32/32 [==============================] - 0s 7ms/step - loss: 1.5568 - accuracy: 0.4580
# [1.5568183660507202, 0.4580000042915344]

# %%
def plot_history(history, title='', axs=None, exp_name=""):
    if axs is not None:
        ax1, ax2 = axs
    else:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    if len(exp_name) > 0 and exp_name[0] != '_':
        exp_name = '_' + exp_name
    ax1.plot(history.history['loss'], label='train' + exp_name)
    ax1.plot(history.history['val_loss'], label='val' + exp_name)
    ax1.set_ylim(0., None)
    ax1.set_title('loss')
    ax1.legend()

    ax2.plot(history.history['accuracy'], label='train accuracy'  + exp_name)
    ax2.plot(history.history['val_accuracy'], label='val accuracy'  + exp_name)
    ax2.set_ylim(0.25, 1.)
    ax2.set_title('Accuracy')
    ax2.legend()
    return (ax1, ax2)

# %%
plot_history(history)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7bb34b2750>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7bb0372d90>)

# %% [markdown]
# ❓ **Question** ❓ Evaluate your model on the test data and compare it with baseline. Are you satisfied with these performances ? Look at PRO TIPS above and iterate a bit if you want to improve!

# %%
# YOUR CODE HERE
model.evaluate(X_test_small,y_test_small)
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 1.5568 - accuracy: 0.4580
# [1.5568183660507202, 0.4580000042915344]

# %% [markdown]
# ## 3. Increase data size

# %% [markdown]
# ❓ **Question** ❓ Now that your model fits on a small subsample, try to fit it on the full dataset and notice how performance increases.
#
# 🚨 **Make sure to use GPU acceleration** by clicking on `"Runtime --> Change runtime --> GPU"` if you are on Colab.
#
# 💡 Training neural network on images (in each batch) can be parallelized, and this parallelization procedure can be done on GPU.

# %%
# YOUR CODE HERE
batch_size = 50
epochs = 25
history = model.fit(X_train, y_train, batch_size=batch_size, 
                              steps_per_epoch=X_train.shape[0] // batch_size, epochs=epochs, verbose=1,
                              #validation_data=(X_test_small,y_test_small)
                              validation_split=0.3)
# Out:
# Epoch 1/25
# 1000/1000 [==============================] - 14s 13ms/step - loss: 1.4888 - accuracy: 0.4715 - val_loss: 1.4764 - val_accuracy: 0.4783
# Epoch 2/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.4115 - accuracy: 0.5014 - val_loss: 1.4050 - val_accuracy: 0.5019
# Epoch 3/25
# 1000/1000 [==============================] - 14s 14ms/step - loss: 1.3574 - accuracy: 0.5236 - val_loss: 1.3785 - val_accuracy: 0.5097
# Epoch 4/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.3118 - accuracy: 0.5359 - val_loss: 1.3366 - val_accuracy: 0.5208
# Epoch 5/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.2732 - accuracy: 0.5531 - val_loss: 1.3214 - val_accuracy: 0.5265
# Epoch 6/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.2278 - accuracy: 0.5683 - val_loss: 1.2805 - val_accuracy: 0.5403
# Epoch 7/25
# 1000/1000 [==============================] - 14s 14ms/step - loss: 1.1973 - accuracy: 0.5793 - val_loss: 1.2493 - val_accuracy: 0.5556
# Epoch 8/25
# 1000/1000 [==============================] - 14s 14ms/step - loss: 1.1616 - accuracy: 0.5915 - val_loss: 1.2350 - val_accuracy: 0.5597
# Epoch 9/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.1352 - accuracy: 0.6017 - val_loss: 1.2063 - val_accuracy: 0.5691
# Epoch 10/25
# 1000/1000 [==============================] - 14s 14ms/step - loss: 1.1058 - accuracy: 0.6112 - val_loss: 1.2056 - val_accuracy: 0.5709
# Epoch 11/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.0806 - accuracy: 0.6201 - val_loss: 1.1780 - val_accuracy: 0.5797
# Epoch 12/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.0563 - accuracy: 0.6311 - val_loss: 1.1592 - val_accuracy: 0.5883
# Epoch 13/25
# 1000/1000 [==============================] - 12s 12ms/step - loss: 1.0253 - accuracy: 0.6432 - val_loss: 1.1538 - val_accuracy: 0.5925
# Epoch 14/25
# 1000/1000 [==============================] - 14s 14ms/step - loss: 1.0100 - accuracy: 0.6466 - val_loss: 1.1403 - val_accuracy: 0.5970
# Epoch 15/25
# 1000/1000 [==============================] - 13s 13ms/step - loss: 0.9858 - accuracy: 0.6559 - val_loss: 1.1460 - val_accuracy: 0.5931
# Epoch 16/25
# 1000/1000 [==============================] - 14s 14ms/step - loss: 0.9669 - accuracy: 0.6652 - val_loss: 1.1184 - val_accuracy: 0.6057
# Epoch 17/25
# 1000/1000 [==============================] - 14s 14ms/step - loss: 0.9434 - accuracy: 0.6724 - val_loss: 1.1083 - val_accuracy: 0.6070
# Epoch 18/25
#  497/1000 [=============>................] - ETA: 5s - loss: 0.9314 - accuracy: 0.6756WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 25000 batches). You may need to use the repeat() function when building your dataset.
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.9307 - accuracy: 0.6757 - val_loss: 1.1060 - val_accuracy: 0.6095

# %%
plot_history(history)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7bb2f64bd0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7bb35a5bd0>)

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.1122 - accuracy: 0.6143
# [1.112225890159607, 0.614300012588501]

# %% [markdown]
# ## 4. Data augmentation
#
# ☝️ It seems that adding pictures greatly improves model performance! Welcome to the Deep Learning paradigm, where big data does make a difference.
#
# To easily improve the accuracy of a model without much work, we can generate new data: the _data augmentation_. This widely used technique consists in applying little transformation to input images without changing its label, as mirroring, cropping, intensity changes, etc. The improved performance simply results from the Neural network training with more different data.
#
# The natural way to generate these new images is to apply some transformations and train the model on the original and new images. However, such procedure requires to keep all these images in memory : it can be very intensive, to the point that your computer memory cannot hold any new image (your computer might even crash).
#
# For this reason, we will augment the data **on the fly** (batch per batch), meaning that we will create new data, use them to fit the model, then delete them. Here, Keras is our friend as it provides the utils to do all this job for us. Look at the following code : the general writing can seem odd but don't be panicked: just look at the function arguments that defines the augmentation techniques that we will use and that you can check in the  [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=(0.8, 1.2),
    ) 

datagen.fit(X_train)
datagen

# %%
X_augmented_iterator = datagen.flow(X_train, shuffle=False, batch_size=1)
X_augmented_iterator

# %% [markdown]
# 💡 Always visualize your data augmentation in order to double check that you can still recognize the label yourself!

# %%
import numpy as np

for i, (raw_image, augmented_image) in enumerate(zip(X_train, X_augmented_iterator)):
    _, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2))
    ax1.imshow(raw_image)
    ax2.imshow(augmented_image[0])
    plt.show()
    
    if i > 10:
        break

# %% [markdown]
# ❗ **Remark** ❗ In this example, there is one augmented image per initial image. In fact, when your model will use `datagen.flow` in the `fit`, it will create one augmentation per epochs! Indeed, the images in the original dataset will not be provided to the optimizer, only augmented ones instead. (But because the augmentations are performed randomly, this allows both modified images and some very close of the originals).
#
# ❓ **Question** ❓ Take time to understand the cell below: Previously, we used the `validation_split` argument to let the model separate a training set from the validation one. It is not possible here as **using an image in the training set and its transformation in the validation set is considered as a data leakage**. Therefore, we have to manually define the `validation_data` with the following commands:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# The model
model_aug = initialize_model()
model_aug = compile_model(model_aug)

# The data generator
X_tr = X_train[:40000]
y_tr = y_train[:40000]
X_val = X_train[40000:]
y_val = y_train[40000:]
train_flow = datagen.flow(X_tr, y_tr, batch_size=64)

# The early stopping criterion
es = EarlyStopping(patience=3)

# The fit
history_aug = model_aug.fit(train_flow, 
                        epochs=50, 
                        callbacks=[es], 
                        validation_data=(X_val, y_val))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adadelta.py:74: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adadelta, self).__init__(name, **kwargs)
# Epoch 1/50
# 625/625 [==============================] - 35s 54ms/step - loss: 2.1003 - accuracy: 0.2377 - val_loss: 1.9393 - val_accuracy: 0.3181
# Epoch 2/50
# 625/625 [==============================] - 33s 53ms/step - loss: 1.8942 - accuracy: 0.3255 - val_loss: 1.7946 - val_accuracy: 0.3664
# Epoch 3/50
# 625/625 [==============================] - 33s 53ms/step - loss: 1.7764 - accuracy: 0.3717 - val_loss: 1.6858 - val_accuracy: 0.4037
# Epoch 4/50
# 625/625 [==============================] - 33s 53ms/step - loss: 1.6959 - accuracy: 0.3988 - val_loss: 1.6176 - val_accuracy: 0.4297
# Epoch 5/50
# 625/625 [==============================] - 34s 55ms/step - loss: 1.6367 - accuracy: 0.4206 - val_loss: 1.5956 - val_accuracy: 0.4353
# Epoch 6/50
# 625/625 [==============================] - 34s 54ms/step - loss: 1.5900 - accuracy: 0.4373 - val_loss: 1.5471 - val_accuracy: 0.4464
# Epoch 7/50
# 625/625 [==============================] - 33s 53ms/step - loss: 1.5546 - accuracy: 0.4500 - val_loss: 1.4836 - val_accuracy: 0.4760
# Epoch 8/50
# 625/625 [==============================] - 34s 54ms/step - loss: 1.5229 - accuracy: 0.4628 - val_loss: 1.4780 - val_accuracy: 0.4765
# Epoch 9/50
# 625/625 [==============================] - 34s 55ms/step - loss: 1.4972 - accuracy: 0.4658 - val_loss: 1.4815 - val_accuracy: 0.4736
# Epoch 10/50
# 625/625 [==============================] - 34s 54ms/step - loss: 1.4698 - accuracy: 0.4757 - val_loss: 1.3994 - val_accuracy: 0.5056
# Epoch 11/50
# 625/625 [==============================] - 35s 56ms/step - loss: 1.4503 - accuracy: 0.4850 - val_loss: 1.4268 - val_accuracy: 0.4913
# Epoch 12/50
# 625/625 [==============================] - 34s 54ms/step - loss: 1.4322 - accuracy: 0.4862 - val_loss: 1.4398 - val_accuracy: 0.4905
# Epoch 13/50
# 625/625 [==============================] - 35s 55ms/step - loss: 1.4146 - accuracy: 0.4957 - val_loss: 1.4298 - val_accuracy: 0.4882

# %% [markdown]
# ❗️❗️ Remark ❗️❗️: The training can be quite long here. Don't hesitate to go to the next exercise and gome back once in a while to finish the last questions
#
# ❓ **Question** ❓ Now, let's plot the previous and current run histories. What do you think of the data augmentation?

# %%
# YOUR CODE HERE
plot_history(history_aug)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f7b3832eb90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f7b382a1d10>)

# %% [markdown]
# 💡 Data augmentation may not improve your performance easily. It strongly depends on the model architecture you used, the learning rate, the type of augmentation chosen, etc...Image classification is an art that takes lots of practice to master!
#
# 🚨 **Don't spend too much time now trying to finetune your model - you have other interesting challenge ahead**.
#
# 📚 [here is a good example of solution for future reference](https://machinelearningmastery.com/how-to-develop-a-cnn-from-scratch-for-cifar-10-photo-classification/). They manage to get about 80% accuracy

# %% [markdown]
# ### 🏁 Congratulation 🏁
